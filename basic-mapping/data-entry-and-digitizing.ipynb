# %% [markdown]
# <a href="https://colab.research.google.com/github/danylcnj/Geography-441-Projects-/blob/main/basic-mapping/data-entry-and-digitizing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Data Entry & Digitizing**

# %% [markdown]
# Created by Nicholas Danylchak
#
# 8/24/25

# %% [markdown]
# ## **Get ready to start**
#
# - Click **`File/Save a copy in Drive`** to save a copy of this notebook to your own Google Drive

# %% [markdown]
# ##**Digitized Township Map**

# %% [markdown]
# Below is a map of May Township prepared following the Week 4 Assignment Guide
#
# ```markdown
# https://drive.google.com/file/d/1dJNYi81LltgZJ5GWM-hT5c14j4JTd015/view?usp=sharing
# ```
#
# Create a viewable link of the map.
# - Delete `/view?usp=sharing`at the end of the link
# - Replace `/file/d/` with `/uc?export=view&id=`
#
#
# ```markdown
# https://drive.google.com/uc?export=view&id=1dJNYi81LltgZJ5GWM-hT5c14j4JTd015
# ```
#
# Reminder of the rendering syntax:
# ```markdown
# ![township map](https://drive.google.com/uc?export=view&id=1dJNYi81LltgZJ5GWM-hT5c14j4JTd015)
# ```
#
# <mark>Insert the map below:</mark>
# <mark>![township map](https://drive.google.com/uc?export=view&id=1dJNYi81LltgZJ5GWM-hT5c14j4JTd015)</mark>
# ```

# %% [markdown]
# ##**Digitized Subdivision Map**

# %% [markdown]
# Below is a map of the digitized subdivision prepared following the Week 4 Assignment Guide
#
# ```markdown
# https://drive.google.com/file/d/1NlFKB020Xm-DcwIBDiOBp7_UjnUg09V0/view?usp=sharing
# ```
#
# Create a viewable link of the map.
# - Delete `/view?usp=sharing`at the end of the link
# - Replace `/file/d/` with `/uc?export=view&id=`
#
#
# ```markdown
# https://drive.google.com/uc?export=view&id=1NlFKB020Xm-DcwIBDiOBp7_UjnUg09V0
# ```
#
# Reminder of the rendering syntax:
# ```markdown
# ![township map](https://drive.google.com/uc?export=view&id=1NlFKB020Xm-DcwIBDiOBp7_UjnUg09V0)
# ```
#
# <mark>Insert the map below:</mark>
#  <mark>![township map](https://drive.google.com/uc?export=view&id=1NlFKB020Xm-DcwIBDiOBp7_UjnUg09V0)</mark>

# %% [markdown]
# ## **Save and share this notebook**
#
# Make sure the notebook is viewable by anyone with the link, then <mark>**submit the shareable link to Canvas for the Week 4 Assignment.**</mark>

# %% [markdown]
# ## **References**
# - [Markdown cheat sheet](https://www.markdownguide.org/cheat-sheet/)
